# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200

# %%
df = pd.read_json("../data/sublocation.json")
df
# Out:
#    situation_view_id        situation_view_name  \
# 0                 54  Ukraine Refugee Situation
# 1                 54  Ukraine Refugee Situation
# 2                 54  Ukraine Refugee Situation
# 3                 54  Ukraine Refugee Situation
# 4                 54  Ukraine Refugee Situation
# 5                 54  Ukraine Refugee Situation
# 6                 54  Ukraine Refugee Situation
# 7                 54  Ukraine Refugee Situation
#
#                           situation_view_description  \
# 0  The escalation of conflict in Ukraine has caus...
# 1  The escalation of conflict in Ukraine has caus...
# 2  The escalation of conflict in Ukraine has caus...
# 3  The escalation of conflict in Ukraine has caus...
# 4  The escalation of conflict in Ukraine has caus...
# 5  The escalation of conflict in Ukraine has caus...
# 6  The escalation of conflict in Ukraine has caus...
# 7  The escalation of conflict in Ukraine has caus...
#
#                                                 data
# 0  {'geomaster_name': 'Poland', 'geomaster_id': 1...
# 1  {'geomaster_name': 'Other European countries',...
# 2  {'geomaster_name': 'Hungary', 'geomaster_id': ...
# 3  {'geomaster_name': 'Slovakia', 'geomaster_id':...
# 4  {'geomaster_name': 'Russian Federation', 'geom...
# 5  {'geomaster_name': 'Republic of Moldova', 'geo...
# 6  {'geomaster_name': 'Romania', 'geomaster_id': ...
# 7  {'geomaster_name': 'Belarus', 'geomaster_id': ...

# %%
pd.DataFrame(df.data.values.tolist())
# Out:
#              geomaster_name  geomaster_id admin_level     centroid_lon  \
# 0                    Poland         10781     Country          19.4013
# 1  Other European countries         10792  Settlement  12.999541505426
# 2                   Hungary         10783     Country          19.4131
# 3                  Slovakia         10785     Country          19.4864
# 4        Russian Federation         10791     Country    38.1556078125
# 5       Republic of Moldova         10784     Country          28.4646
# 6                   Romania         10782     Country             25.3
# 7                   Belarus         10786     Country          28.0463
#
#       centroid_lat    lat_max    lon_max    lat_min    lon_min source  ...  \
# 0          52.1224  55.469506  26.401300  48.021549  12.401300   None  ...
# 1  49.284734814307  51.315890  19.828251  47.368175  14.696223   None  ...
# 2          47.1672  54.167200  26.588881  43.760061  12.413100   None  ...
# 3          48.7062  55.706200  26.486400  41.706200  12.486400   None  ...
# 4  51.488850139616  59.067055  36.958298  54.998769  31.669526   None  ...
# 5          47.1976  54.197600  35.464600  40.197600  21.464600   None  ...
# 6          45.8667  52.866700  32.300000  38.866700  18.300000   None  ...
# 7          53.5384  57.838934  33.727941  48.496894  21.046300   None  ...
#
#                             population_groups_concat population_group_id  \
# 0   Ukrainian Asylum-seekers/applications cumulative                5460
# 1  Ukrainian Asylum-seekers/applications (since 2...                5459
# 2   Ukrainian Asylum-seekers/applications cumulative                5460
# 3   Ukrainian Asylum-seekers/applications cumulative                5460
# 4   Ukrainian Asylum-seekers/applications cumulative                5460
# 5   Ukrainian Asylum-seekers/applications cumulative                5460
# 6   Ukrainian Asylum-seekers/applications cumulative                5460
# 7   Ukrainian Asylum-seekers/applications cumulative                5460
#
#   individuals_type demography_type individuals households  \
# 0                2               1     1720227          0
# 1                1               0      304156          0
# 2                2               1      255291          0
# 3                2               1      204862          0
# 4                2               1      131365          0
# 5                2               1      106994          0
# 6                2               1       84671          0
# 7                2               1        1226          0
#
#                                    population_groups published numChildren  \
# 0  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 1  [{'id': '5459', 'name': 'Ukrainian Asylum-seek...     False           0
# 2  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 3  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 4  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 5  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 6  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 7  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
#
#      color
# 0  #3c8dbc
# 1  #3c8dbc
# 2  #3c8dbc
# 3  #3c8dbc
# 4  #3c8dbc
# 5  #3c8dbc
# 6  #3c8dbc
# 7  #3c8dbc
#
# [8 rows x 23 columns]

# %% [markdown]
# Data courtesy of UNHCR

# %%
pd.DataFrame(df.data.values.tolist())
# Out:
#              geomaster_name  geomaster_id admin_level     centroid_lon  \
# 0                    Poland         10781     Country          19.4013
# 1  Other European countries         10792  Settlement  12.999541505426
# 2                   Hungary         10783     Country          19.4131
# 3                  Slovakia         10785     Country          19.4864
# 4        Russian Federation         10791     Country    38.1556078125
# 5       Republic of Moldova         10784     Country          28.4646
# 6                   Romania         10782     Country             25.3
# 7                   Belarus         10786     Country          28.0463
#
#       centroid_lat    lat_max    lon_max    lat_min    lon_min source  ...  \
# 0          52.1224  55.469506  26.401300  48.021549  12.401300   None  ...
# 1  49.284734814307  51.315890  19.828251  47.368175  14.696223   None  ...
# 2          47.1672  54.167200  26.588881  43.760061  12.413100   None  ...
# 3          48.7062  55.706200  26.486400  41.706200  12.486400   None  ...
# 4  51.488850139616  59.067055  36.958298  54.998769  31.669526   None  ...
# 5          47.1976  54.197600  35.464600  40.197600  21.464600   None  ...
# 6          45.8667  52.866700  32.300000  38.866700  18.300000   None  ...
# 7          53.5384  57.838934  33.727941  48.496894  21.046300   None  ...
#
#                             population_groups_concat population_group_id  \
# 0   Ukrainian Asylum-seekers/applications cumulative                5460
# 1  Ukrainian Asylum-seekers/applications (since 2...                5459
# 2   Ukrainian Asylum-seekers/applications cumulative                5460
# 3   Ukrainian Asylum-seekers/applications cumulative                5460
# 4   Ukrainian Asylum-seekers/applications cumulative                5460
# 5   Ukrainian Asylum-seekers/applications cumulative                5460
# 6   Ukrainian Asylum-seekers/applications cumulative                5460
# 7   Ukrainian Asylum-seekers/applications cumulative                5460
#
#   individuals_type demography_type individuals households  \
# 0                2               1     1720227          0
# 1                1               0      304156          0
# 2                2               1      255291          0
# 3                2               1      204862          0
# 4                2               1      131365          0
# 5                2               1      106994          0
# 6                2               1       84671          0
# 7                2               1        1226          0
#
#                                    population_groups published numChildren  \
# 0  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 1  [{'id': '5459', 'name': 'Ukrainian Asylum-seek...     False           0
# 2  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 3  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 4  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 5  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 6  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
# 7  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...     False           0
#
#      color
# 0  #3c8dbc
# 1  #3c8dbc
# 2  #3c8dbc
# 3  #3c8dbc
# 4  #3c8dbc
# 5  #3c8dbc
# 6  #3c8dbc
# 7  #3c8dbc
#
# [8 rows x 23 columns]

# %% [markdown]
# [Good information about this on Stack Overflow](https://stackoverflow.com/questions/20638006/convert-list-of-dictionaries-to-a-pandas-dataframe)

# %%
dfdf = pd.DataFrame(df.data.values.tolist())
dfdf.plot.bar(x="geomaster_name", y="individuals")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-abc3cc2ee64c> in <module>
#       1 dfdf = pd.DataFrame(df.data.values.tolist())
# ----> 2 dfdf.plot.bar(x="geomaster_name", y="individuals")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
dfdf.individuals = dfdf.individuals.astype(int)
dfdf = dfdf.sort_values(by="individuals")
dfdf.index = [1, 2, 3, 4, 5, 6, 0, 7]
dfdf = dfdf.sort_index()
dfdf.plot.barh(x="geomaster_name", y="individuals")
plt.barh(dfdf.geomaster_name, dfdf.individuals)
plt.savefig('ukraine1.pdf', dpi=300, bbox_inches='tight')

# %%
dfdf
dfdf.index = [1, 2, 3, 4, 5, 6, 0, 7]
dfdf
# Out:
#              geomaster_name  geomaster_id admin_level     centroid_lon  \
# 1  Other European countries         10792  Settlement  12.999541505426
# 2                   Belarus         10786     Country          28.0463
# 3                   Romania         10782     Country             25.3
# 4       Republic of Moldova         10784     Country          28.4646
# 5        Russian Federation         10791     Country    38.1556078125
# 6                  Slovakia         10785     Country          19.4864
# 0                   Hungary         10783     Country          19.4131
# 7                    Poland         10781     Country          19.4013
#
#       centroid_lat    lat_max    lon_max    lat_min    lon_min source  ...  \
# 1  49.284734814307  51.315890  19.828251  47.368175  14.696223   None  ...
# 2          53.5384  57.838934  33.727941  48.496894  21.046300   None  ...
# 3          45.8667  52.866700  32.300000  38.866700  18.300000   None  ...
# 4          47.1976  54.197600  35.464600  40.197600  21.464600   None  ...
# 5  51.488850139616  59.067055  36.958298  54.998769  31.669526   None  ...
# 6          48.7062  55.706200  26.486400  41.706200  12.486400   None  ...
# 0          47.1672  54.167200  26.588881  43.760061  12.413100   None  ...
# 7          52.1224  55.469506  26.401300  48.021549  12.401300   None  ...
#
#                             population_groups_concat population_group_id  \
# 1  Ukrainian Asylum-seekers/applications (since 2...                5459
# 2   Ukrainian Asylum-seekers/applications cumulative                5460
# 3   Ukrainian Asylum-seekers/applications cumulative                5460
# 4   Ukrainian Asylum-seekers/applications cumulative                5460
# 5   Ukrainian Asylum-seekers/applications cumulative                5460
# 6   Ukrainian Asylum-seekers/applications cumulative                5460
# 0   Ukrainian Asylum-seekers/applications cumulative                5460
# 7   Ukrainian Asylum-seekers/applications cumulative                5460
#
#   individuals_type demography_type individuals households  \
# 1                1               0      304156          0
# 2                2               1        1226          0
# 3                2               1       84671          0
# 4                2               1      106994          0
# 5                2               1      131365          0
# 6                2               1      204862          0
# 0                2               1      255291          0
# 7                2               1     1720227          0
#
#                                    population_groups  published numChildren  \
# 1  [{'id': '5459', 'name': 'Ukrainian Asylum-seek...      False           0
# 2  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
# 3  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
# 4  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
# 5  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
# 6  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
# 0  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
# 7  [{'id': '5460', 'name': 'Ukrainian Asylum-seek...      False           0
#
#      color
# 1  #3c8dbc
# 2  #3c8dbc
# 3  #3c8dbc
# 4  #3c8dbc
# 5  #3c8dbc
# 6  #3c8dbc
# 0  #3c8dbc
# 7  #3c8dbc
#
# [8 rows x 23 columns]

# %%
my_range = list(range(1, len(df.index) + 1))
fig, ax = plt.subplots(figsize=(6, 4))

plt.hlines(y=my_range, 
           xmin=0, 
           xmax=dfdf['individuals'] / 1e6, 
           color='#007ACC', 
           alpha=0.2, 
           linewidth=10
          )

plt.plot(dfdf['individuals'] / 1e6, 
         my_range, 
         'o', 
         markersize=10,
         markeredgewidth=0,
         color='#007ACC', 
         alpha=0.6
        )

ax.set_xlabel('Million refuges', 
              fontsize=18, 
              fontweight='black', 
              color = '#333F4B'
             )
# ax.set_ylabel('')

ax.tick_params(axis='both', 
               which='major', 
               labelsize=12
              )

plt.yticks(my_range,
           dfdf.geomaster_name
          )

# # add an horizonal label for the y axis 
fig.text(-0.27, 0.96, 
         'Receiving country', 
         fontsize=18, 
         fontweight='black', 
         color='#333F4B')

# # change the style of the axis spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_bounds((1, len(my_range)))
ax.set_xlim(0, 1.8)

ax.spines['left'].set_position(('outward', 8))
ax.spines['bottom'].set_position(('outward', 5))

plt.savefig('ukraine2.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Exercises
#
# 1. Annotate bars with the number of people
# 2. Make an upright version of the plot with red-colored bars and oblique labels, like here: *put link*
